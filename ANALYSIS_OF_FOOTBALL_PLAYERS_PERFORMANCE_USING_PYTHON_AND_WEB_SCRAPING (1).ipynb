# %%
# !pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install beautifulsoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install csv
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement csv (from versions: none)
# ERROR: No matching distribution found for csv

# %%
import requests
from bs4 import BeautifulSoup
import csv

url = "https://fbref.com/en/squads/822bd0ba/Liverpool-Stats"
response = requests.get(url)
content = response.content

soup = BeautifulSoup(content, 'html.parser')

table = soup.find('table', class_='stats_table')

if table is not None:
    headers = table.find('thead').find_all('th')
    column_names = [header.text.strip() for header in headers]

    rows = table.find('tbody').find_all('tr')
    player_data = []
    for row in rows:
        player_row = [data.text.strip() for data in row.find_all('td')]
        player_data.append(player_row)

    # Save data to CSV file
    filename = "liverpool_stats.csv"
    with open(filename, 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(column_names)
        writer.writerows(player_data)

    print("Data saved to", filename)
else:
    print("Table not found on the webpage.")
# Out:
# Data saved to liverpool_stats.csv

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dt = pd.read_csv("liverpool_stats.csv")

# %%
dt
# Out:
#    Unnamed: 0 Playing Time  Performance  Expected  Progression Per 90 Minutes  \
# 0      br BRA           GK           29        37           37          3,330
# 1      eg EGY           FW           30        38           37          3,290
# 2     eng ENG           DF           23        37           34          2,923
# 3      nl NED           DF           31        32           32          2,835
# 4      br BRA           MF           28        36           31          2,671
# 5     sct SCO           DF           28        34           29          2,583
# 6     eng ENG           MF           32        35           23          2,074
# 7      uy URU           FW           23        29           19          1,695
# 8     eng ENG        MF,FW           19        32           18          1,613
# 9      fr FRA           DF           23        18           17          1,552
# 10     nl NED        FW,MF           23        21           17          1,458
# ...

# %%
dt.head()
# Out:
#   Unnamed: 0 Playing Time  Performance  Expected  Progression Per 90 Minutes  \
# 0     br BRA           GK           29        37           37          3,330
# 1     eg EGY           FW           30        38           37          3,290
# 2    eng ENG           DF           23        37           34          2,923
# 3     nl NED           DF           31        32           32          2,835
# 4     br BRA           MF           28        36           31          2,671
#
#    Unnamed: 6  Player  Nation   Pos  ...  Ast.1    G+A.1  G-PK.1  G+A-PK  \
# 0        37.0     0.0     1.0   1.0  ...   0.01  Matches     NaN     NaN
# 1        36.6    19.0    12.0  31.0  ...   0.72  Matches     NaN     NaN
# 2        32.5     2.0     9.0  11.0  ...   0.43  Matches     NaN     NaN
# 3        31.5     3.0     1.0   4.0  ...   0.12  Matches     NaN     NaN
# 4        29.7     0.0     2.0   2.0  ...   0.10  Matches     NaN     NaN
#
#    xG.1  xAG.1  xG+xAG  npxG.1  npxG+xAG.1  Matches
# ...

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 41 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      35 non-null     object
#  1   Playing Time    35 non-null     object
#  2   Performance     35 non-null     int64
#  3   Expected        35 non-null     int64
#  4   Progression     35 non-null     int64
#  5   Per 90 Minutes  28 non-null     object
#  6   Unnamed: 6      28 non-null     float64
#  7   Player          28 non-null     float64
#  8   Nation          28 non-null     float64
#  9   Pos             28 non-null     float64
#  10  Age             28 non-null     float64
#  11  MP              28 non-null     float64
#  12  Starts          28 non-null     float64
#  13  Min             28 non-null     float64
#  14  90s             28 non-null     float64
#  15  Gls             28 non-null     float64
#  16  Ast             28 non-null     float64
# ...

# %%
dt.describe()
# Out:
#        Performance   Expected  Progression  Unnamed: 6     Player     Nation  \
# count    35.000000  35.000000    35.000000   28.000000  28.000000  28.000000
# mean     24.742857  16.628571    11.942857   14.914286   2.535714   2.071429
# std       5.298961  13.638367    11.970412   11.301482   4.417827   3.042034
# min      16.000000   0.000000     0.000000    0.100000   0.000000   0.000000
# 25%      20.500000   1.500000     0.500000    5.325000   0.000000   0.000000
# 50%      25.000000  18.000000    11.000000   13.050000   0.500000   1.000000
# 75%      28.500000  30.000000    17.500000   19.850000   3.000000   2.250000
# max      36.000000  38.000000    37.000000   37.000000  19.000000  12.000000
#
#              Pos        Age         MP     Starts  ...      Gls.1      Ast.1  \
# count  28.000000  28.000000  28.000000  28.000000  ...  28.000000  28.000000
# mean    4.607143   2.464286   0.071429   0.142857  ...   0.159643   0.274643
# ...

# %%
dt.isnull()
# Out:
#     Unnamed: 0  Playing Time  Performance  Expected  Progression  \
# 0        False         False        False     False        False
# 1        False         False        False     False        False
# 2        False         False        False     False        False
# 3        False         False        False     False        False
# 4        False         False        False     False        False
# 5        False         False        False     False        False
# 6        False         False        False     False        False
# 7        False         False        False     False        False
# 8        False         False        False     False        False
# 9        False         False        False     False        False
# 10       False         False        False     False        False
# 11       False         False        False     False        False
# 12       False         False        False     False        False
# ...

# %%
dt.count
# Out:
# <bound method DataFrame.count of    Unnamed: 0 Playing Time  Performance  Expected  Progression Per 90 Minutes  \
# 0      br BRA           GK           29        37           37          3,330
# 1      eg EGY           FW           30        38           37          3,290
# 2     eng ENG           DF           23        37           34          2,923
# 3      nl NED           DF           31        32           32          2,835
# 4      br BRA           MF           28        36           31          2,671
# 5     sct SCO           DF           28        34           29          2,583
# 6     eng ENG           MF           32        35           23          2,074
# 7      uy URU           FW           23        29           19          1,695
# 8     eng ENG        MF,FW           19        32           18          1,613
# 9      fr FRA           DF           23        18           17          1,552
# 10     nl NED        FW,MF           23        21           17          1,458
# ...

# %%
# Create a correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(dt.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()
# Out:
# <ipython-input-38-afc556cdce97>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(dt.corr(), annot=True, cmap='coolwarm')

# %%
# Plotting analysis
plt.figure(figsize=(10, 6))
plt.scatter(dt['Age'], dt['Gls'], color='red')
plt.xlabel("Age")
plt.ylabel("Gls")
plt.title("Age vs Goals")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=dt['Nation'], y=dt['Ast'])
plt.xlabel("Nation")
plt.ylabel("Ast")
plt.title("Nation vs Assists")
plt.show()

# %%
# Calculate POSITIVE accuracy
accuracy = len(dt[dt['Player'] == 'DF']) / len(dt) * 100
print("Accuracy (DF):", accuracy, "%")

accuracy = len(dt[dt['Player'] == 'MF']) / len(dt) * 100
print("Accuracy (MF):", accuracy, "%")
# Out:
# Accuracy (DF): 0.0 %
# Accuracy (MF): 0.0 %

# %%
import scipy.stats as stats
# Perform inferential statistics
nation_counts = dt['Nation'].value_counts()
print("Nation Counts:")
print(nation_counts)
# Out:
# Nation Counts:
# 0.0     12
# 2.0      5
# 1.0      4
# 4.0      3
# 12.0     1
# 9.0      1
# 8.0      1
# 3.0      1
# Name: Nation, dtype: int64

# %%
# Perform t-test between 'Goals' of English (ENG) and Non-English players
eng_goals = dt[dt['Nation'] == 'ENG']['Gls']
non_eng_goals = dt[dt['Nation'] != 'ENG']['Gls']
t_stat, p_value = stats.ttest_ind(eng_goals, non_eng_goals)
print("T-Test Results:")
print("T-Statistic:", t_stat)
print("P-Value:", p_value)
# Out:
# T-Test Results:
# T-Statistic: nan
# P-Value: nan

# %%
# Summary graph
plt.figure(figsize=(10, 6))
sns.countplot(x='Pos', data=dt)
plt.xlabel("Pos")
plt.ylabel("Count")
plt.title("Distribution of Players by Position")
plt.show()
